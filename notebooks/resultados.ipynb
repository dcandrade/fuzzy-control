# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('altura_sem_vazao.txt').set_index('tempo')
df.columns = ['sem vazão']
plot = df.plot();
plot.set_xlabel('Tempo (s)')
plot.set_ylabel('Altura (m)')
# Out:
# Text(0,0.5,'Altura (m)')

# %%
df_vazao = pd.read_csv('altura_com_vazao.txt').set_index('tempo')
df_vazao.columns = ['com vazão']
plot = df_vazao.plot();
plot.set_xlabel('Tempo (s)')
plot.set_ylabel('Altura (m)')
# Out:
# Text(0,0.5,'Altura (m)')

# %%
plot = pd.concat([df, df_vazao], axis=1).plot()
plot.set_xlabel('Tempo (s)')
plot.set_ylabel('Altura (m)')
# Out:
# Text(0,0.5,'Altura (m)')

# %% [markdown]
# ### resultados

# %%
t1 = pd.read_csv('var_1.txt').set_index('tempo')
t1.columns = ['Temperatura', 'Altura', 'Vazão','Vazão Ideal', 'Temperatura Ideal']
t1.head()
# Out:
#        Temperatura    Altura     Vazão  Vazão Ideal  Temperatura Ideal
# tempo
# 1        50.686513  1.158450  0.008854        0.084              30.75
# 2        43.012346  1.860886  0.009530        0.084              30.75
# 3        39.674482  2.551945  0.012079        0.084              30.75
# 4        37.797522  3.238429  0.014145        0.084              30.75
# 5        36.593633  3.922387  0.015934        0.084              30.75

# %%
t1[['Vazão', 'Vazão Ideal']].plot()
plt.xlabel('Tempo (s)')
plt.ylabel('Vazão (m^3/s)')
plt.title('Variação dos Parâmetros\nEvolução da Vazão na Variação #1')
plt.savefig('variacao-parametros/vazao1.eps', format='eps')

# %%
plot = t1[['Temperatura', 'Temperatura Ideal']].plot()
plt.xlabel('Tempo (s)')
plt.ylabel('Temperatura (ºCelsius)')
plt.title('Variação dos Parâmetros\nEvolução da Temperatura na Variação #1')
plt.savefig('variacao-parametros/temperatura1.eps', format='eps')

# %% [markdown]
# ### caso 2

# %%
t2 = pd.read_csv('var_2.txt').set_index('tempo')
t2.columns = ['Temperatura', 'Altura', 'Vazão','Vazão Ideal', 'Temperatura Ideal']
t2.head()
# Out:
#        Temperatura    Altura     Vazão  Vazão Ideal  Temperatura Ideal
# tempo
# 1        -5.319308  2.158158  0.012522        0.084               57.0
# 2        13.595697  2.869242  0.013008        0.084               57.0
# 3        24.939231  3.576899  0.014998        0.084               57.0
# 4        32.414721  4.274732  0.016746        0.084               57.0
# 5        37.735717  4.966666  0.018307        0.084               57.0

# %%
t2[['Vazão', 'Vazão Ideal']].plot()
plt.xlabel('Tempo (s)')
plt.ylabel('Vazão (m^3/s)')
plt.title('Variação dos Parâmetros\nEvolução da Vazão na Variação #2')
plt.savefig('variacao-parametros/vazao2.eps', format='eps')

# %%
plot = t2[['Temperatura', 'Temperatura Ideal']].plot()
plt.xlabel('Tempo (s)')
plt.ylabel('Temperatura (ºCelsius)')
plt.title('Variação dos Parâmetros\nEvolução da Temperatura na Configuração #2')
plt.savefig('variacao-parametros/temperatura2.eps', format='eps')

# %% [markdown]
# ### Caso 3

# %%
t3 = pd.read_csv('var_3.txt').set_index('tempo')
t3.columns = ['Temperatura', 'Altura', 'Vazão','Vazão Ideal', 'Temperatura Ideal']
t3.head()
# Out:
#        Temperatura    Altura     Vazão  Vazão Ideal  Temperatura Ideal
# tempo
# 1        39.000000  0.159155  0.000000        0.084               28.0
# 2        24.077760  0.850647  0.003532        0.084               28.0
# 3        32.909709  1.307350  0.008166        0.084               28.0
# 4        28.768320  1.989671  0.010124        0.084               28.0
# 5        26.777237  2.647671  0.012490        0.084               28.0

# %%
t3[['Vazão', 'Vazão Ideal']].plot()
plt.xlabel('Tempo (s)')
plt.ylabel('Vazão (m^3/s)')
plt.title('Variação dos Parâmetros\nEvolução da Vazão na Variação #3')
plt.savefig('variacao-parametros/vazao3.eps', format='eps')

# %%
plot = t3[['Temperatura', 'Temperatura Ideal']].plot()
plt.xlabel('Tempo (s)')
plt.ylabel('Temperatura (ºCelsius)')
plt.title('Variação dos Parâmetros\nEvolução da Temperatura na Variação #3')
plt.savefig('variacao-parametros/temperatura3.eps', format='eps')

# %% [markdown]
# ### variação dos conjuntos fuzzy para o caso 2

# %%
tf2 = pd.read_csv('var_2_set.txt').set_index('tempo')
tf2.columns = ['Temperatura (Nova Fuzzificação)', 'Altura', 'Vazão (Nova Fuzzificação)','Vazão Ideal', 'Temperatura Ideal']
tf2.head()
# Out:
#        Temperatura (Nova Fuzzificação)    Altura  Vazão (Nova Fuzzificação)  \
# tempo
# 1                            -5.319308  2.158158                   0.012522
# 2                            11.937983  3.053229                   0.013008
# 3                            21.368424  3.948104                   0.015472
# 4                            27.312282  4.842810                   0.017594
# 5                            31.401376  5.737365                   0.019485
#
#        Vazão Ideal  Temperatura Ideal
# tempo
# 1            0.084               57.0
# 2            0.084               57.0
# 3            0.084               57.0
# 4            0.084               57.0
# 5            0.084               57.0

# %%
tf2['Temperatura (Fuzzificação Original)'] = t2['Temperatura']
tf2['Vazão (Fuzzificação Original)'] = t2['Vazão']

tf2.head()
# Out:
#        Temperatura (Nova Fuzzificação)    Altura  Vazão (Nova Fuzzificação)  \
# tempo
# 1                            -5.319308  2.158158                   0.012522
# 2                            11.937983  3.053229                   0.013008
# 3                            21.368424  3.948104                   0.015472
# 4                            27.312282  4.842810                   0.017594
# 5                            31.401376  5.737365                   0.019485
#
#        Vazão Ideal  Temperatura Ideal  Temperatura (Fuzzificação Original)  \
# tempo
# 1            0.084               57.0                            -5.319308
# 2            0.084               57.0                            13.595697
# 3            0.084               57.0                            24.939231
# 4            0.084               57.0                            32.414721
# 5            0.084               57.0                            37.735717
#
#        Vazão (Fuzzificação Original)
# ...

# %%
tf2[['Vazão (Nova Fuzzificação)', 'Vazão Ideal', 'Vazão (Fuzzificação Original)']].plot()
plt.xlabel('Tempo (s)')
plt.ylabel('Vazão (m^3/s)')
plt.title('Varianção da Fuzzificação\nEvolução da Vazão na Configuração #2')
plt.savefig('variacao-conjuntos/vazao.eps', format='eps')

# %%
plot = tf2[['Temperatura (Nova Fuzzificação)', 'Temperatura Ideal', 'Temperatura (Fuzzificação Original)']].plot()
plt.xlabel('Tempo (s)')
plt.ylabel('Temperatura (ºCelsius)')
plt.title('Varianção da Fuzzificação\nEvolução da Temperatura na Configuração #2')
plt.savefig('variacao-conjuntos/temperatura.eps', format='eps')

# %% [markdown]
# ### variação defuzzy

# %%
tf2 = pd.read_csv('var_2_defuzz.txt').set_index('tempo')
tf2.columns = ['Temperatura (Nova Defuzzificação)', 'Altura', 'Vazão (Nova Defuzzificação)','Vazão Ideal', 'Temperatura Ideal']
tf2.head()
# Out:
#        Temperatura (Nova Defuzzificação)    Altura  \
# tempo
# 1                              -5.319308  2.158158
# 2                              13.356046  2.789665
# 3                              25.079957  3.417979
# 4                              33.031899  4.036152
# 5                              38.809172  4.648090
#
#        Vazão (Nova Defuzzificação)  Vazão Ideal  Temperatura Ideal
# tempo
# 1                         0.012522        0.084               57.0
# 2                         0.013008        0.084               57.0
# 3                         0.014789        0.084               57.0
# 4                         0.016370        0.084               57.0
# 5                         0.017789        0.084               57.0

# %%
tf2['Temperatura (Defuzzificação Original)'] = t2['Temperatura']
tf2['Vazão (Defuzzificação Original)'] = t2['Vazão']

tf2.head()
# Out:
#        Temperatura (Nova Defuzzificação)    Altura  \
# tempo
# 1                              -5.319308  2.158158
# 2                              13.356046  2.789665
# 3                              25.079957  3.417979
# 4                              33.031899  4.036152
# 5                              38.809172  4.648090
#
#        Vazão (Nova Defuzzificação)  Vazão Ideal  Temperatura Ideal  \
# tempo
# 1                         0.012522        0.084               57.0
# 2                         0.013008        0.084               57.0
# 3                         0.014789        0.084               57.0
# 4                         0.016370        0.084               57.0
# 5                         0.017789        0.084               57.0
#
#        Temperatura (Defuzzificação Original)  Vazão (Defuzzificação Original)
# tempo
# 1                                  -5.319308                         0.012522
# ...

# %%
tf2[['Vazão (Nova Defuzzificação)', 'Vazão Ideal', 'Vazão (Defuzzificação Original)']].plot()
plt.xlabel('Tempo (s)')
plt.ylabel('Vazão (m^3/s)')
plt.title('Variação da Defuzzificação\nEvolução da Vaão na Configuração #2')
plt.savefig('variacao-defuz/vazao.eps', format='eps')

# %%
plot = tf2[['Temperatura (Nova Defuzzificação)', 'Temperatura Ideal', 'Temperatura (Defuzzificação Original)']].plot()
plt.xlabel('Tempo (s)')
plt.ylabel('Temperatura (ºCelsius)')
plt.title('Variação da Defuzzificação\nEvolução da Temperatura na Configuração #2')
plt.savefig('variacao-defuz/temperatura.eps', format='eps')

# %% [markdown]
# #### Variação Regras

# %%
tf2 = pd.read_csv('var_2_regras.txt').set_index('tempo')
tf2.columns = ['Temperatura (Novas Regras)', 'Altura', 'Vazão (Novas Regras)','Vazão Ideal', 'Temperatura Ideal']
tf2.head()
# Out:
#        Temperatura (Novas Regras)    Altura  Vazão (Novas Regras)  \
# tempo
# 1                       -5.319308  2.158158              0.012522
# 2                       13.595697  2.869242              0.013008
# 3                       24.939231  3.576899              0.014998
# 4                       32.414721  4.274732              0.016746
# 5                       37.735717  4.966666              0.018307
#
#        Vazão Ideal  Temperatura Ideal
# tempo
# 1            0.084               57.0
# 2            0.084               57.0
# 3            0.084               57.0
# 4            0.084               57.0
# 5            0.084               57.0

# %%
tf2['Temperatura (Regras Originais)'] = t2['Temperatura']
tf2['Vazão (Regras Originais)'] = t2['Vazão']

tf2.head()
# Out:
#        Temperatura (Novas Regras)    Altura  Vazão (Novas Regras)  \
# tempo
# 1                       -5.319308  2.158158              0.012522
# 2                       13.595697  2.869242              0.013008
# 3                       24.939231  3.576899              0.014998
# 4                       32.414721  4.274732              0.016746
# 5                       37.735717  4.966666              0.018307
#
#        Vazão Ideal  Temperatura Ideal  Temperatura (Regras Originais)  \
# tempo
# 1            0.084               57.0                       -5.319308
# 2            0.084               57.0                       13.595697
# 3            0.084               57.0                       24.939231
# 4            0.084               57.0                       32.414721
# 5            0.084               57.0                       37.735717
#
#        Vazão (Regras Originais)
# tempo
# 1                      0.012522
# 2                      0.013008
# ...

# %%
tf2[['Vazão (Novas Regras)', 'Vazão Ideal', 'Vazão (Regras Originais)']].plot()
plt.xlabel('Tempo (s)')
plt.ylabel('Vazão (m^3/s)')
plt.title('Variação das Regras de Controle\nEvolução da Vazão na Configuração #2')
plt.savefig('variacao-regras/vazao.eps', format='eps')

# %%
plot = tf2[['Temperatura (Novas Regras)', 'Temperatura Ideal', 'Temperatura (Regras Originais)']].plot()
plt.xlabel('Tempo (s)')
plt.ylabel('Temperatura (ºCelsius)')
plt.title('Variação das Regras de Controle\nEvolução da Temperatura na Configuração #2')
plt.savefig('variacao-regras/temperatura.eps', format='eps')
